# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(1234)

device
# Out:
# device(type='cuda', index=0)

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform = ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform = ToTensor()
)


train_dataloader = DataLoader(training_data, batch_size=1024, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=1024)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(784, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)

# %%
learning_rate = 0.01
batch_size = 256
epochs = 50

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

# optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.314399  [    0/60000]
# Test Error:
#  Accuracy: 21.4%, Avg loss: 2.245233
#
# Epoch 2
# -------------------------------
# loss: 2.244173  [    0/60000]
# Test Error:
#  Accuracy: 37.5%, Avg loss: 2.161864
#
# Epoch 3
# -------------------------------
# loss: 2.170574  [    0/60000]
# Test Error:
#  Accuracy: 44.5%, Avg loss: 2.024909
#
# Epoch 4
# -------------------------------
# loss: 2.020008  [    0/60000]
# Test Error:
#  Accuracy: 48.7%, Avg loss: 1.822750
#
# Epoch 5
# -------------------------------
# loss: 1.821193  [    0/60000]
# Test Error:
#  Accuracy: 57.0%, Avg loss: 1.603126
#
# Epoch 6
# -------------------------------
# loss: 1.622494  [    0/60000]
# Test Error:
#  Accuracy: 61.2%, Avg loss: 1.417443
#
# Epoch 7
# -------------------------------
# loss: 1.411869  [    0/60000]
# Test Error:
#  Accuracy: 61.1%, Avg loss: 1.276150
#
# Epoch 8
# -------------------------------
# loss: 1.261782  [    0/60000]
# Test Error:
#  Accuracy: 61.7%, Avg loss: 1.170341
#
# Epoch 9
# -------------------------------
# loss: 1.188527  [    0/60000]
# Test Error:
#  Accuracy: 62.8%, Avg loss: 1.090120
#
# Epoch 10
# -------------------------------
# loss: 1.043404  [    0/60000]
# Test Error:
#  Accuracy: 64.2%, Avg loss: 1.027691
#
# Epoch 11
# -------------------------------
# loss: 1.016436  [    0/60000]
# Test Error:
#  Accuracy: 65.4%, Avg loss: 0.977819
#
# Epoch 12
# -------------------------------
# loss: 0.937417  [    0/60000]
# Test Error:
#  Accuracy: 65.8%, Avg loss: 0.936836
#
# Epoch 13
# -------------------------------
# loss: 0.932771  [    0/60000]
# Test Error:
#  Accuracy: 66.5%, Avg loss: 0.902882
#
# Epoch 14
# -------------------------------
# loss: 0.875520  [    0/60000]
# Test Error:
#  Accuracy: 67.3%, Avg loss: 0.875038
#
# Epoch 15
# -------------------------------
# loss: 0.855611  [    0/60000]
# Test Error:
#  Accuracy: 68.8%, Avg loss: 0.849928
#
# Epoch 16
# -------------------------------
# loss: 0.804213  [    0/60000]
# Test Error:
#  Accuracy: 68.6%, Avg loss: 0.828974
#
# Epoch 17
# -------------------------------
# loss: 0.815129  [    0/60000]
# Test Error:
#  Accuracy: 69.7%, Avg loss: 0.809841
#
# Epoch 18
# -------------------------------
# loss: 0.793391  [    0/60000]
# Test Error:
#  Accuracy: 70.3%, Avg loss: 0.793320
#
# Epoch 19
# -------------------------------
# loss: 0.811126  [    0/60000]
# Test Error:
#  Accuracy: 70.7%, Avg loss: 0.779622
#
# Epoch 20
# -------------------------------
# loss: 0.764285  [    0/60000]
# Test Error:
#  Accuracy: 71.4%, Avg loss: 0.765024
#
# Epoch 21
# -------------------------------
# loss: 0.698024  [    0/60000]
# Test Error:
#  Accuracy: 71.8%, Avg loss: 0.752841
#
# Epoch 22
# -------------------------------
# loss: 0.737685  [    0/60000]
# Test Error:
#  Accuracy: 72.4%, Avg loss: 0.741114
#
# Epoch 23
# -------------------------------
# loss: 0.725755  [    0/60000]
# Test Error:
#  Accuracy: 73.0%, Avg loss: 0.730585
#
# Epoch 24
# -------------------------------
# loss: 0.707519  [    0/60000]
# Test Error:
#  Accuracy: 73.5%, Avg loss: 0.720685
#
# Epoch 25
# -------------------------------
# loss: 0.691800  [    0/60000]
# Test Error:
#  Accuracy: 73.9%, Avg loss: 0.711593
#
# Epoch 26
# -------------------------------
# loss: 0.694376  [    0/60000]
# Test Error:
#  Accuracy: 74.6%, Avg loss: 0.703175
#
# Epoch 27
# -------------------------------
# loss: 0.656811  [    0/60000]
# Test Error:
#  Accuracy: 74.8%, Avg loss: 0.693748
#
# Epoch 28
# -------------------------------
# loss: 0.685332  [    0/60000]
# Test Error:
#  Accuracy: 75.2%, Avg loss: 0.685331
#
# Epoch 29
# -------------------------------
# loss: 0.689249  [    0/60000]
# Test Error:
#  Accuracy: 75.8%, Avg loss: 0.677579
#
# Epoch 30
# -------------------------------
# loss: 0.657816  [    0/60000]
# Test Error:
#  Accuracy: 76.2%, Avg loss: 0.670420
#
# Epoch 31
# -------------------------------
# loss: 0.680845  [    0/60000]
# Test Error:
#  Accuracy: 76.5%, Avg loss: 0.662383
#
# Epoch 32
# -------------------------------
# loss: 0.610529  [    0/60000]
# Test Error:
#  Accuracy: 76.7%, Avg loss: 0.656231
#
# Epoch 33
# -------------------------------
# loss: 0.625695  [    0/60000]
# Test Error:
#  Accuracy: 76.9%, Avg loss: 0.648689
#
# Epoch 34
# -------------------------------
# loss: 0.631836  [    0/60000]
# Test Error:
#  Accuracy: 77.3%, Avg loss: 0.643496
#
# Epoch 35
# -------------------------------
# loss: 0.632462  [    0/60000]
# Test Error:
#  Accuracy: 77.5%, Avg loss: 0.636319
#
# Epoch 36
# -------------------------------
# loss: 0.609889  [    0/60000]
# Test Error:
#  Accuracy: 77.8%, Avg loss: 0.630006
#
# Epoch 37
# -------------------------------
# loss: 0.622902  [    0/60000]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.624707
#
# Epoch 38
# -------------------------------
# loss: 0.597488  [    0/60000]
# Test Error:
#  Accuracy: 78.1%, Avg loss: 0.619754
#
# Epoch 39
# -------------------------------
# loss: 0.610951  [    0/60000]
# Test Error:
#  Accuracy: 78.2%, Avg loss: 0.614382
#
# Epoch 40
# -------------------------------
# loss: 0.578175  [    0/60000]
# Test Error:
#  Accuracy: 78.4%, Avg loss: 0.609699
#
# Epoch 41
# -------------------------------
# loss: 0.589898  [    0/60000]
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.604550
#
# Epoch 42
# -------------------------------
# loss: 0.575130  [    0/60000]
# Test Error:
#  Accuracy: 79.1%, Avg loss: 0.599812
#
# Epoch 43
# -------------------------------
# loss: 0.570493  [    0/60000]
# Test Error:
#  Accuracy: 79.2%, Avg loss: 0.596300
#
# Epoch 44
# -------------------------------
# loss: 0.582644  [    0/60000]
# Test Error:
#  Accuracy: 79.4%, Avg loss: 0.591186
#
# Epoch 45
# -------------------------------
# loss: 0.588754  [    0/60000]
# Test Error:
#  Accuracy: 79.3%, Avg loss: 0.587254
#
# Epoch 46
# -------------------------------
# loss: 0.552098  [    0/60000]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.583656
#
# Epoch 47
# -------------------------------
# loss: 0.593512  [    0/60000]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.579543
#
# Epoch 48
# -------------------------------
# loss: 0.574515  [    0/60000]
# Test Error:
#  Accuracy: 79.7%, Avg loss: 0.576189
#
# Epoch 49
# -------------------------------
# loss: 0.547007  [    0/60000]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.572507
#
# Epoch 50
# -------------------------------
# loss: 0.526761  [    0/60000]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.571350
#
# Done!
