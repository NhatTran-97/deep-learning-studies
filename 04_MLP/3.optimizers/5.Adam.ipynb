# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(1234)

device
# Out:
# device(type='cuda', index=0)

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform = ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform = ToTensor()
)


train_dataloader = DataLoader(training_data, batch_size=1024, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=1024)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(784, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)

# %%
learning_rate = 0.01
batch_size = 256
epochs = 50

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

# optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.314399  [    0/60000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.501172
#
# Epoch 2
# -------------------------------
# loss: 0.491128  [    0/60000]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.413957
#
# Epoch 3
# -------------------------------
# loss: 0.406111  [    0/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.391032
#
# Epoch 4
# -------------------------------
# loss: 0.362574  [    0/60000]
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.381274
#
# Epoch 5
# -------------------------------
# loss: 0.322637  [    0/60000]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.364026
#
# Epoch 6
# -------------------------------
# loss: 0.285767  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.353167
#
# Epoch 7
# -------------------------------
# loss: 0.276089  [    0/60000]
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.370231
#
# Epoch 8
# -------------------------------
# loss: 0.298020  [    0/60000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.353019
#
# Epoch 9
# -------------------------------
# loss: 0.292971  [    0/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.341983
#
# Epoch 10
# -------------------------------
# loss: 0.259500  [    0/60000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.359168
#
# Epoch 11
# -------------------------------
# loss: 0.256520  [    0/60000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.370708
#
# Epoch 12
# -------------------------------
# loss: 0.263686  [    0/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.342627
#
# Epoch 13
# -------------------------------
# loss: 0.198662  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.353205
#
# Epoch 14
# -------------------------------
# loss: 0.227886  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.350117
#
# Epoch 15
# -------------------------------
# loss: 0.215534  [    0/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.350762
#
# Epoch 16
# -------------------------------
# loss: 0.184262  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.358416
#
# Epoch 17
# -------------------------------
# loss: 0.200545  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.371707
#
# Epoch 18
# -------------------------------
# loss: 0.254822  [    0/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.355541
#
# Epoch 19
# -------------------------------
# loss: 0.188967  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.359773
#
# Epoch 20
# -------------------------------
# loss: 0.191729  [    0/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.361151
#
# Epoch 21
# -------------------------------
# loss: 0.146844  [    0/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.373481
#
# Epoch 22
# -------------------------------
# loss: 0.202417  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.359959
#
# Epoch 23
# -------------------------------
# loss: 0.198438  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.370829
#
# Epoch 24
# -------------------------------
# loss: 0.226905  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.404864
#
# Epoch 25
# -------------------------------
# loss: 0.177524  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.402133
#
# Epoch 26
# -------------------------------
# loss: 0.231075  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.360882
#
# Epoch 27
# -------------------------------
# loss: 0.160698  [    0/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.389723
#
# Epoch 28
# -------------------------------
# loss: 0.205609  [    0/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.384968
#
# Epoch 29
# -------------------------------
# loss: 0.194276  [    0/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.395828
#
# Epoch 30
# -------------------------------
# loss: 0.152541  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.408096
#
# Epoch 31
# -------------------------------
# loss: 0.175169  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.395682
#
# Epoch 32
# -------------------------------
# loss: 0.165783  [    0/60000]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.459121
#
# Epoch 33
# -------------------------------
# loss: 0.188561  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.408950
#
# Epoch 34
# -------------------------------
# loss: 0.134102  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.398045
#
# Epoch 35
# -------------------------------
# loss: 0.141299  [    0/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.402910
#
# Epoch 36
# -------------------------------
# loss: 0.133488  [    0/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.409363
#
# Epoch 37
# -------------------------------
# loss: 0.150749  [    0/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.438906
#
# Epoch 38
# -------------------------------
# loss: 0.152465  [    0/60000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.434551
#
# Epoch 39
# -------------------------------
# loss: 0.187675  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.435224
#
# Epoch 40
# -------------------------------
# loss: 0.142927  [    0/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.456782
#
# Epoch 41
# -------------------------------
# loss: 0.155543  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.454632
#
# Epoch 42
# -------------------------------
# loss: 0.122737  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.456756
#
# Epoch 43
# -------------------------------
# loss: 0.127157  [    0/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.477758
#
# Epoch 44
# -------------------------------
# loss: 0.154439  [    0/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.473740
#
# Epoch 45
# -------------------------------
# loss: 0.134731  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.489469
#
# Epoch 46
# -------------------------------
# loss: 0.147936  [    0/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.473521
#
# Epoch 47
# -------------------------------
# loss: 0.158433  [    0/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.482690
#
# Epoch 48
# -------------------------------
# loss: 0.148634  [    0/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.460994
#
# Epoch 49
# -------------------------------
# loss: 0.114895  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.506323
#
# Epoch 50
# -------------------------------
# loss: 0.121503  [    0/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.498351
#
# Done!
