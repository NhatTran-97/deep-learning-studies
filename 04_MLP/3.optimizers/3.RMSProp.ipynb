# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(1234)

device
# Out:
# device(type='cuda', index=0)

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform = ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform = ToTensor()
)


train_dataloader = DataLoader(training_data, batch_size=1024, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=1024)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(784, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)

# %%
learning_rate = 0.01
batch_size = 256
epochs = 50

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

# optimizer
optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.314399  [    0/60000]
# Test Error:
#  Accuracy: 72.5%, Avg loss: 0.699368
#
# Epoch 2
# -------------------------------
# loss: 0.672832  [    0/60000]
# Test Error:
#  Accuracy: 72.2%, Avg loss: 0.732891
#
# Epoch 3
# -------------------------------
# loss: 0.723506  [    0/60000]
# Test Error:
#  Accuracy: 75.4%, Avg loss: 0.626243
#
# Epoch 4
# -------------------------------
# loss: 0.624667  [    0/60000]
# Test Error:
#  Accuracy: 71.9%, Avg loss: 0.812675
#
# Epoch 5
# -------------------------------
# loss: 0.793611  [    0/60000]
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.521769
#
# Epoch 6
# -------------------------------
# loss: 0.484270  [    0/60000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.492143
#
# Epoch 7
# -------------------------------
# loss: 0.415219  [    0/60000]
# Test Error:
#  Accuracy: 77.4%, Avg loss: 0.633240
#
# Epoch 8
# -------------------------------
# loss: 0.569613  [    0/60000]
# Test Error:
#  Accuracy: 81.5%, Avg loss: 0.503059
#
# Epoch 9
# -------------------------------
# loss: 0.487040  [    0/60000]
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.495384
#
# Epoch 10
# -------------------------------
# loss: 0.442403  [    0/60000]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.458937
#
# Epoch 11
# -------------------------------
# loss: 0.395651  [    0/60000]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.459619
#
# Epoch 12
# -------------------------------
# loss: 0.419688  [    0/60000]
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.523536
#
# Epoch 13
# -------------------------------
# loss: 0.474446  [    0/60000]
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.501884
#
# Epoch 14
# -------------------------------
# loss: 0.437084  [    0/60000]
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.486772
#
# Epoch 15
# -------------------------------
# loss: 0.432958  [    0/60000]
# Test Error:
#  Accuracy: 79.8%, Avg loss: 0.532222
#
# Epoch 16
# -------------------------------
# loss: 0.465093  [    0/60000]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.426752
#
# Epoch 17
# -------------------------------
# loss: 0.372555  [    0/60000]
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.418374
#
# Epoch 18
# -------------------------------
# loss: 0.346696  [    0/60000]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.397050
#
# Epoch 19
# -------------------------------
# loss: 0.328098  [    0/60000]
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.417450
#
# Epoch 20
# -------------------------------
# loss: 0.345176  [    0/60000]
# Test Error:
#  Accuracy: 56.1%, Avg loss: 2.438150
#
# Epoch 21
# -------------------------------
# loss: 2.313387  [    0/60000]
# Test Error:
#  Accuracy: 85.0%, Avg loss: 0.407511
#
# Epoch 22
# -------------------------------
# loss: 0.340073  [    0/60000]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.402779
#
# Epoch 23
# -------------------------------
# loss: 0.349882  [    0/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.386805
#
# Epoch 24
# -------------------------------
# loss: 0.355598  [    0/60000]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.399158
#
# Epoch 25
# -------------------------------
# loss: 0.296348  [    0/60000]
# Test Error:
#  Accuracy: 81.3%, Avg loss: 0.521107
#
# Epoch 26
# -------------------------------
# loss: 0.486920  [    0/60000]
# Test Error:
#  Accuracy: 80.3%, Avg loss: 0.540234
#
# Epoch 27
# -------------------------------
# loss: 0.478010  [    0/60000]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.426135
#
# Epoch 28
# -------------------------------
# loss: 0.370501  [    0/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.395551
#
# Epoch 29
# -------------------------------
# loss: 0.334328  [    0/60000]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.398788
#
# Epoch 30
# -------------------------------
# loss: 0.322888  [    0/60000]
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.454665
#
# Epoch 31
# -------------------------------
# loss: 0.379050  [    0/60000]
# Test Error:
#  Accuracy: 83.6%, Avg loss: 0.451548
#
# Epoch 32
# -------------------------------
# loss: 0.378613  [    0/60000]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.444049
#
# Epoch 33
# -------------------------------
# loss: 0.344931  [    0/60000]
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.441004
#
# Epoch 34
# -------------------------------
# loss: 0.367462  [    0/60000]
# Test Error:
#  Accuracy: 85.6%, Avg loss: 0.389676
#
# Epoch 35
# -------------------------------
# loss: 0.296821  [    0/60000]
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.415976
#
# Epoch 36
# -------------------------------
# loss: 0.332795  [    0/60000]
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.396911
#
# Epoch 37
# -------------------------------
# loss: 0.311369  [    0/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.444499
#
# Epoch 38
# -------------------------------
# loss: 0.348410  [    0/60000]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.418876
#
# Epoch 39
# -------------------------------
# loss: 0.337299  [    0/60000]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.428651
#
# Epoch 40
# -------------------------------
# loss: 0.324615  [    0/60000]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.462740
#
# Epoch 41
# -------------------------------
# loss: 0.349310  [    0/60000]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.395354
#
# Epoch 42
# -------------------------------
# loss: 0.326357  [    0/60000]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.460269
#
# Epoch 43
# -------------------------------
# loss: 0.351164  [    0/60000]
# Test Error:
#  Accuracy: 85.9%, Avg loss: 0.415860
#
# Epoch 44
# -------------------------------
# loss: 0.279156  [    0/60000]
# Test Error:
#  Accuracy: 84.8%, Avg loss: 0.421989
#
# Epoch 45
# -------------------------------
# loss: 0.335047  [    0/60000]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.419103
#
# Epoch 46
# -------------------------------
# loss: 0.297816  [    0/60000]
# Test Error:
#  Accuracy: 86.7%, Avg loss: 0.389258
#
# Epoch 47
# -------------------------------
# loss: 0.313587  [    0/60000]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.541382
#
# Epoch 48
# -------------------------------
# loss: 0.491244  [    0/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.385424
#
# Epoch 49
# -------------------------------
# loss: 0.237683  [    0/60000]
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.435266
#
# Epoch 50
# -------------------------------
# loss: 0.241346  [    0/60000]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.443013
#
# Done!
