# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(1234)

device
# Out:
# device(type='cuda', index=0)

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform = ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform = ToTensor()
)


train_dataloader = DataLoader(training_data, batch_size=1024, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=1024)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(784, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)

# %%
learning_rate = 0.01
batch_size = 256
epochs = 50

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

# optimizer
optimizer = torch.optim.Adagrad(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.314399  [    0/60000]
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.675538
#
# Epoch 2
# -------------------------------
# loss: 0.647190  [    0/60000]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.566062
#
# Epoch 3
# -------------------------------
# loss: 0.563007  [    0/60000]
# Test Error:
#  Accuracy: 80.9%, Avg loss: 0.524766
#
# Epoch 4
# -------------------------------
# loss: 0.538875  [    0/60000]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.469866
#
# Epoch 5
# -------------------------------
# loss: 0.453782  [    0/60000]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.447185
#
# Epoch 6
# -------------------------------
# loss: 0.425647  [    0/60000]
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.429815
#
# Epoch 7
# -------------------------------
# loss: 0.373753  [    0/60000]
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.435481
#
# Epoch 8
# -------------------------------
# loss: 0.410359  [    0/60000]
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.426550
#
# Epoch 9
# -------------------------------
# loss: 0.421790  [    0/60000]
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.406019
#
# Epoch 10
# -------------------------------
# loss: 0.367621  [    0/60000]
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.407473
#
# Epoch 11
# -------------------------------
# loss: 0.378937  [    0/60000]
# Test Error:
#  Accuracy: 85.2%, Avg loss: 0.409266
#
# Epoch 12
# -------------------------------
# loss: 0.361681  [    0/60000]
# Test Error:
#  Accuracy: 86.0%, Avg loss: 0.391099
#
# Epoch 13
# -------------------------------
# loss: 0.344668  [    0/60000]
# Test Error:
#  Accuracy: 86.3%, Avg loss: 0.386486
#
# Epoch 14
# -------------------------------
# loss: 0.312031  [    0/60000]
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.390451
#
# Epoch 15
# -------------------------------
# loss: 0.346646  [    0/60000]
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.383431
#
# Epoch 16
# -------------------------------
# loss: 0.314070  [    0/60000]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.378110
#
# Epoch 17
# -------------------------------
# loss: 0.309072  [    0/60000]
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.373630
#
# Epoch 18
# -------------------------------
# loss: 0.330619  [    0/60000]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.372199
#
# Epoch 19
# -------------------------------
# loss: 0.302782  [    0/60000]
# Test Error:
#  Accuracy: 86.8%, Avg loss: 0.372274
#
# Epoch 20
# -------------------------------
# loss: 0.300609  [    0/60000]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.370332
#
# Epoch 21
# -------------------------------
# loss: 0.290545  [    0/60000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.364211
#
# Epoch 22
# -------------------------------
# loss: 0.313579  [    0/60000]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.367494
#
# Epoch 23
# -------------------------------
# loss: 0.337375  [    0/60000]
# Test Error:
#  Accuracy: 87.2%, Avg loss: 0.357284
#
# Epoch 24
# -------------------------------
# loss: 0.341135  [    0/60000]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.367572
#
# Epoch 25
# -------------------------------
# loss: 0.286769  [    0/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.358753
#
# Epoch 26
# -------------------------------
# loss: 0.307305  [    0/60000]
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.385446
#
# Epoch 27
# -------------------------------
# loss: 0.315991  [    0/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.357203
#
# Epoch 28
# -------------------------------
# loss: 0.305528  [    0/60000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.362629
#
# Epoch 29
# -------------------------------
# loss: 0.322781  [    0/60000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.361098
#
# Epoch 30
# -------------------------------
# loss: 0.304837  [    0/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.351301
#
# Epoch 31
# -------------------------------
# loss: 0.297331  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.349075
#
# Epoch 32
# -------------------------------
# loss: 0.283343  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.345907
#
# Epoch 33
# -------------------------------
# loss: 0.266949  [    0/60000]
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.352401
#
# Epoch 34
# -------------------------------
# loss: 0.271870  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.351639
#
# Epoch 35
# -------------------------------
# loss: 0.277533  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.346746
#
# Epoch 36
# -------------------------------
# loss: 0.266796  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.349186
#
# Epoch 37
# -------------------------------
# loss: 0.293757  [    0/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.342341
#
# Epoch 38
# -------------------------------
# loss: 0.303234  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.353840
#
# Epoch 39
# -------------------------------
# loss: 0.285928  [    0/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.345778
#
# Epoch 40
# -------------------------------
# loss: 0.280155  [    0/60000]
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.359439
#
# Epoch 41
# -------------------------------
# loss: 0.277575  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.343980
#
# Epoch 42
# -------------------------------
# loss: 0.263301  [    0/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.340671
#
# Epoch 43
# -------------------------------
# loss: 0.256348  [    0/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.340580
#
# Epoch 44
# -------------------------------
# loss: 0.251448  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.335738
#
# Epoch 45
# -------------------------------
# loss: 0.252240  [    0/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.343350
#
# Epoch 46
# -------------------------------
# loss: 0.242797  [    0/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.338564
#
# Epoch 47
# -------------------------------
# loss: 0.305473  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.338176
#
# Epoch 48
# -------------------------------
# loss: 0.276738  [    0/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.337267
#
# Epoch 49
# -------------------------------
# loss: 0.228559  [    0/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.339077
#
# Epoch 50
# -------------------------------
# loss: 0.203441  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.340677
#
# Done!
