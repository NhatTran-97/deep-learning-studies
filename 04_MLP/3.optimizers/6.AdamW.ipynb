# %%
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.manual_seed(1234)

device
# Out:
# device(type='cuda', index=0)

# %%
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform = ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform = ToTensor()
)


train_dataloader = DataLoader(training_data, batch_size=1024, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=1024)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(784, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)

# %%
learning_rate = 0.01
batch_size = 256
epochs = 50

# Initialize the loss function
loss_fn = nn.CrossEntropyLoss()

# optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")


def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.314399  [    0/60000]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.496976
#
# Epoch 2
# -------------------------------
# loss: 0.490050  [    0/60000]
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.416367
#
# Epoch 3
# -------------------------------
# loss: 0.411121  [    0/60000]
# Test Error:
#  Accuracy: 85.1%, Avg loss: 0.400591
#
# Epoch 4
# -------------------------------
# loss: 0.366467  [    0/60000]
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.373124
#
# Epoch 5
# -------------------------------
# loss: 0.312448  [    0/60000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.358398
#
# Epoch 6
# -------------------------------
# loss: 0.277471  [    0/60000]
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.353906
#
# Epoch 7
# -------------------------------
# loss: 0.284313  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.348611
#
# Epoch 8
# -------------------------------
# loss: 0.279181  [    0/60000]
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.352734
#
# Epoch 9
# -------------------------------
# loss: 0.282206  [    0/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.348036
#
# Epoch 10
# -------------------------------
# loss: 0.253113  [    0/60000]
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.351658
#
# Epoch 11
# -------------------------------
# loss: 0.262995  [    0/60000]
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.372154
#
# Epoch 12
# -------------------------------
# loss: 0.263481  [    0/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.339072
#
# Epoch 13
# -------------------------------
# loss: 0.208838  [    0/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.337048
#
# Epoch 14
# -------------------------------
# loss: 0.219937  [    0/60000]
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.374920
#
# Epoch 15
# -------------------------------
# loss: 0.230345  [    0/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.354755
#
# Epoch 16
# -------------------------------
# loss: 0.209876  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.341752
#
# Epoch 17
# -------------------------------
# loss: 0.175498  [    0/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.355436
#
# Epoch 18
# -------------------------------
# loss: 0.241632  [    0/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.367811
#
# Epoch 19
# -------------------------------
# loss: 0.204415  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.360073
#
# Epoch 20
# -------------------------------
# loss: 0.199961  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.356152
#
# Epoch 21
# -------------------------------
# loss: 0.160993  [    0/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.376923
#
# Epoch 22
# -------------------------------
# loss: 0.200654  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.361023
#
# Epoch 23
# -------------------------------
# loss: 0.187812  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.376924
#
# Epoch 24
# -------------------------------
# loss: 0.221685  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.377078
#
# Epoch 25
# -------------------------------
# loss: 0.182548  [    0/60000]
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.399822
#
# Epoch 26
# -------------------------------
# loss: 0.219378  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.385018
#
# Epoch 27
# -------------------------------
# loss: 0.162368  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.389269
#
# Epoch 28
# -------------------------------
# loss: 0.205360  [    0/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.372603
#
# Epoch 29
# -------------------------------
# loss: 0.204416  [    0/60000]
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.391983
#
# Epoch 30
# -------------------------------
# loss: 0.153052  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.388210
#
# Epoch 31
# -------------------------------
# loss: 0.171980  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.398490
#
# Epoch 32
# -------------------------------
# loss: 0.156363  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.396184
#
# Epoch 33
# -------------------------------
# loss: 0.173941  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.400880
#
# Epoch 34
# -------------------------------
# loss: 0.161497  [    0/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.398201
#
# Epoch 35
# -------------------------------
# loss: 0.154507  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.389106
#
# Epoch 36
# -------------------------------
# loss: 0.141206  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.395889
#
# Epoch 37
# -------------------------------
# loss: 0.182522  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.419892
#
# Epoch 38
# -------------------------------
# loss: 0.162924  [    0/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.405062
#
# Epoch 39
# -------------------------------
# loss: 0.157186  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.419074
#
# Epoch 40
# -------------------------------
# loss: 0.148743  [    0/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.446461
#
# Epoch 41
# -------------------------------
# loss: 0.151765  [    0/60000]
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.436237
#
# Epoch 42
# -------------------------------
# loss: 0.138214  [    0/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.450210
#
# Epoch 43
# -------------------------------
# loss: 0.182949  [    0/60000]
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.430270
#
# Epoch 44
# -------------------------------
# loss: 0.131000  [    0/60000]
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.435173
#
# Epoch 45
# -------------------------------
# loss: 0.122373  [    0/60000]
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.434044
#
# Epoch 46
# -------------------------------
# loss: 0.138007  [    0/60000]
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.432619
#
# Epoch 47
# -------------------------------
# loss: 0.200155  [    0/60000]
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.442210
#
# Epoch 48
# -------------------------------
# loss: 0.153759  [    0/60000]
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.463162
#
# Epoch 49
# -------------------------------
# loss: 0.132519  [    0/60000]
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.476475
#
# Epoch 50
# -------------------------------
# loss: 0.141429  [    0/60000]
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.422548
#
# Done!
