# %% [markdown]
# <h1>What is a Data Structure</h1>
# <h3>A data structure is a way of organizing, managing, and storing data in a computer so that it can be accessed and used efficiently. It defines the layout and organization of data elements in memory and how they interact with each other. Data structures are fundamental to computer science and are used extensively in programming, algorithms, and software development.</h3>
# <h3>In Python, data structures are a critical part of the language, and Python provides several built-in data structures for organizing and managing data efficiently. Here’s an overview of the most common data structures in Python:</h3>

# %% [markdown]
# ![image.png](attachment:ce500b07-6277-4e58-b993-027f173354d0.png)

# %% [markdown]
# <h3>Common Data Structure for Machine Learning</h3>

# %% [markdown]
# ![image.png](attachment:8c315e5d-608b-4243-9068-b378b98e994b.png)
